# %%
# for some basic operations
import numpy as np 
import pandas as pd 

# for visualizations
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# for providing path
import os
print(os.listdir("../input"))
# Out:
# ['Topic_Survey_Assignment.csv']

# %%
# importing the dataset

data = pd.read_csv('../input/Topic_Survey_Assignment.csv')

# check the shape
data.shape
# Out:
# (6, 4)

# %%
# printing the dataset

data.head(6)
# Out:
#                    Unnamed: 0       ...        Not interested
# 0   Big Data (Spark / Hadoop)       ...                   127
# 1  Data Analysis / Statistics       ...                    60
# 2             Data Journalism       ...                   610
# 3          Data Visualization       ...                   102
# 4               Deep Learning       ...                   136
# 5            Machine Learning       ...                    74
#
# [6 rows x 4 columns]

# %%
plt.rcParams['figure.figsize'] = (18, 7)
plt.style.use('fivethirtyeight')

color = plt.cm.cool(np.linspace(0, 1, 3))
d = data.plot.bar(color = color, width = 0.8)
plt.xticks(np.arange(6), ('Big Data', 'Data Analysis', 'Data Journalism',
                                    'Data Visualization', 'Deep Learning', 'Machine Learning'))
plt.legend(loc = 'upper right')
plt.title('Distribution of Students according to choices', fontsize = 20)
plt.show()
